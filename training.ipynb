# %% [markdown]
# ### PANDAS

# %% [markdown]
# # These are Python import commands. They load different libraries into your program so you can use their functions easily.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the CSV (Comma-Separated Values) file from the given file path
# # and store its contents in a Pandas DataFrame named 'data'.

# %%
data=pd.read_csv("/workspaces/amazon-best-selling-books/Amazon_BestSelling_Books_500.csv")

# %% [markdown]
# # Display a summary of the DataFrame, including:
# # - Total number of rows and columns
# # - Column names
# # - Number of non-null (non-missing) v

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            500 non-null    int64
#  1   Title           500 non-null    str
#  2   Author          500 non-null    str
#  3   Category        500 non-null    str
#  4   Sub-Genre       500 non-null    str
#  5   Format          500 non-null    str
#  6   Price (USD)     500 non-null    float64
#  7   Rating          500 non-null    float64
#  8   Reviews         500 non-null    float64
#  9   Weeks on List   500 non-null    float64
#  10  Publisher       500 non-null    str
#  11  Year Published  500 non-null    float64
#  12  ISBN            500 non-null    str
#  13  Amazon BSR      500 non-null    float64
#  14  Amazon URL      500 non-null    str
# dtypes: float64(6), int64(1), str(8)
# memory usage: 58.7 KB

# %% [markdown]
# # Display one random row from the DataFrame

# %%
data.sample()
# Out:
#     Rank           Title                 Author Category        Sub-Genre  \
# 96    97  Nurse Revealed  Emily St. John Mandel  Fiction  Climate Fiction
#
#        Format  Price (USD)  Rating  Reviews  Weeks on List     Publisher  \
# 96  Paperback         9.44     3.9  43877.0           48.0  Anchor Books
#
#     Year Published               ISBN  Amazon BSR Amazon URL
# 96          2022.0  978-0-24089-541-2      2360.0       View

# %% [markdown]
#  # Displays the first 5 rows of the DataFrame by default.

# %%
data.head()
# Out:
#    Rank                       Title           Author     Category  \
# 0     1         The Let Them Theory      Mel Robbins  Non-Fiction
# 1     2            The Dinner Party  Freida McFadden      Fiction
# 2     3           Project Hail Mary        Andy Weir      Fiction
# 3     4  The Correspondent: A Novel   Virginia Evans      Fiction
# 4     5               Atomic Habits      James Clear  Non-Fiction
#
#                   Sub-Genre     Format  Price (USD)  Rating   Reviews  \
# 0                 Self-Help  Paperback        14.99     4.7   98000.0
# 1    Psychological Thriller  Paperback        11.69     4.3    1800.0
# 2           Science Fiction  Paperback        12.99     4.8  130000.0
# 3          Literary Fiction  Hardcover        19.58     4.6   87363.0
# 4  Self-Help / Productivity  Paperback        16.99     4.8  120000.0
#
#    Weeks on List             Publisher  Year Published               ISBN  \
# ...

# %% [markdown]
# # Check for missing (null) values in each column of the DataFrame

# %%
data.isnull().sum()
# Out:
# Rank              0
# Title             0
# Author            0
# Category          0
# Sub-Genre         0
# Format            0
# Price (USD)       0
# Rating            0
# Reviews           0
# Weeks on List     0
# Publisher         0
# Year Published    0
# ISBN              0
# Amazon BSR        0
# Amazon URL        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            500 non-null    int64
#  1   Title           500 non-null    str
#  2   Author          500 non-null    str
#  3   Category        500 non-null    str
#  4   Sub-Genre       500 non-null    str
#  5   Format          500 non-null    str
#  6   Price (USD)     500 non-null    float64
#  7   Rating          500 non-null    float64
#  8   Reviews         500 non-null    float64
#  9   Weeks on List   500 non-null    float64
#  10  Publisher       500 non-null    str
#  11  Year Published  500 non-null    float64
#  12  ISBN            500 non-null    str
#  13  Amazon BSR      500 non-null    float64
#  14  Amazon URL      500 non-null    str
# dtypes: float64(6), int64(1), str(8)
# memory usage: 58.7 KB

# %% [markdown]
# # Select the 'Author' column from the DataFrame
# # Count how many times each author appears in the column
# # Print the frequency of each author

# %%
print(data['Author'].value_counts())
# Out:
# Author
# Taylor Jenkins Reid    8
# Colleen Hoover         8
# Matthew Stover         8
# Daniel Kahneman        8
# Ta-Nehisi Coates       7
#                       ..
# Kevin J. Anderson      1
# Daniel Silva           1
# Angela Duckworth       1
# Dan Simmons            1
# Alastair Reynolds      1
# Name: count, Length: 168, dtype: int64

# %% [markdown]
# # Create a horizontal bar chart from the data

# %%
data.plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Plot the data as a histogram
# # A histogram shows how the data values are distributed into different ranges (bins)
# # It helps you understand the frequency of values in the dataset

# %%
data.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Maps individuals observations along a Cartesian plane to illustrate potential relationships correlations between two numericals variables.

# %%
data.plot(kind='scatter',x='Rating',y='Reviews',color='darkgreen',alpha=0.5)
# Out:
# <Axes: xlabel='Rating', ylabel='Reviews'>
